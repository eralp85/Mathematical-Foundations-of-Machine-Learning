# %% [markdown]
# # SOLVING LINEAR SYSTEMS
#
# ## SUBSTITUTION
#
# Substitution method is used for whenever there is a variable in a system with a coefficient of 1.
#
# For Example, when we are solving for x and y in the following system:
#
# y = 3x
# -5x + 2y =2
#
# System of two equations and variable y in the first equation has a coefficient of 1. We can use substitution method to solve this system.
#
# We can substitute the first equation into the second equation and solve for x.
#
# -5x + 2(3x) = 2
# -5x + 6x = 2
# x = 2
# y = 3(2) = 6

# %% [markdown]
# ## EXERCISES
#
# ### Exercise 1
#
# Solve the following system of equations using substitution method.
#
# x + y = 6 and 2x + 3y = 16
#
# x = 6 - y
#
# 2(6 - y) + 3y = 16
# 12 - 2y + 3y = 16
# 12 + y = 16
# y = 4
# x = 6 - 4 = 2
#
# ### Exercise 2
#
# Solve the following system of equations using substitution method.
#
# -x + 4y = 0 and 2x - 5y = -6
#
# -x = -4y
# x = 4y
#
# 2(4y) - 5y = -6
# 8y - 5y = -6
# 3y = -6
# y = -2
# x = 4(-2) = -8
#
# ### Exercise 3
#
# Solve the following system of equations using substitution method.
#
# y = 4x +1 and -4x + y = 2
#
# no solution

# %% [markdown]
# ## ELIMINATION
#
# Elimination method is used for whenever there is a variable in a system with a coefficient other than 1.
#
# It uses addition property of equations to eliminate variables.
#
# -if necessary, multiply one or both equations by a constant to create opposite coefficients for one of the variables.
#
#
# For Example, when we are solving for x and y in the following system:
#
# 2x - 3y = 15
# 4x + 10y = 14
#
# System of two equations and variable x in the first equation has a coefficient of 2. We can use elimination method to solve this system.
#
# We can multiply the first equation by -2 and add it to the second equation to eliminate x.
#
# -2(2x - 3y = 15)
# -4x + 6y = -30
# 4x + 10y = 14
# 16y = -16
# y = -1
# 2x - 3(-1) = 15
# 2x + 3 = 15
# 2x = 12
# x = 6

# %% [markdown]
# ### Exercise 1
#
# Solve the following system of equations using elimination method.
#
# 4x - 3y = 25 and -3x + 8y = 10
#
# 4x - 3y = 25
# -3x + 8y = 10
#
# 12x - 9y = 75
# -12x + 32y = 40
#
# 23y = 115
#
# y = 5
#
# 4x - 3(5) = 25
#
# 4x = 40
#
# x = 10
#
# ### Exercise 2
#
# Solve the following system of equations using elimination method.
#
# -9x - 15y = -15 and 3x + 5y = -10
#
# -9x - 15y = -15
# 3x + 5y = -10
#
# -27x - 45y = -45
# 27x + 45y = -90
#
# No Solution
#
# ### Exercise 3
#
# Solve the following system of equations using elimination method.
#
# 4x + 2y = 4 and -5x - 3y = -7
#
# 4x + 2y = 4
# -5x - 3y = -7
#
# -20x - 10y = -20
# -20x - 12y = -28
#
# 2y = 8
#
# y = 4
#
# 4x + 2(4) = 4
#
# 4x = -4
#
# x = -1
